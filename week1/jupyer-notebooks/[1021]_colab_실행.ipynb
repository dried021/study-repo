# %% [markdown]
# <a href="https://colab.research.google.com/github/dried021/study-repo/blob/comment/%5B1021%5D_colab_%EC%8B%A4%ED%96%89.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.8.0+cu126
# CUDA available: True
# CUDA device: Tesla T4

# %%
# !git clone https://github.com/dried021/study-repo.git
# %cd study-repo
# !ls -la
# Out:
# Cloning into 'study-repo'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 25 (delta 0), reused 19 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (25/25), 784.46 KiB | 3.24 MiB/s, done.
# /content/study-repo
# total 1112
# drwxr-xr-x 4 root root    4096 Oct 21 07:43  .
# drwxr-xr-x 1 root root    4096 Oct 21 07:43  ..
# -rw-r--r-- 1 root root 1088756 Oct 21 07:43 '[1014]_torchvision_finetuning.ipynb'
# -rw-r--r-- 1 root root     557 Oct 21 07:43  config.py
# -rw-r--r-- 1 root root    3933 Oct 21 07:43  download_data.py
# drwxr-xr-x 8 root root    4096 Oct 21 07:43  .git
# -rw-r--r-- 1 root root      19 Oct 21 07:43  .gitignore
# -rw-r--r-- 1 root root    4148 Oct 21 07:43  main_test.py
# -rw-r--r-- 1 root root    3321 Oct 21 07:43  main_train.py
# -rw-r--r-- 1 root root     274 Oct 21 07:43  README.md
# ...

# %%
# !pip install -q torch torchvision pillow matplotlib numpy

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 463 bytes | 463.00 KiB/s, done.
# From https://github.com/dried021/study-repo
#  * branch            main       -> FETCH_HEAD
#    93b5d31..f2db761  main       -> origin/main
# Updating 93b5d31..f2db761
# Fast-forward
#  src/test.py | 16 +++++++++++++++-
#  1 file changed, 15 insertions(+), 1 deletion(-)

# %%
# !python download_data.py --save_dir ./data
# Out:
# ...
# 100% 9.91M/9.91M [00:00<00:00, 18.5MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 490kB/s]
# 100% 1.65M/1.65M [00:00<00:00, 4.68MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 21.4MB/s]
# Converting MNIST train data...
# 100% 60000/60000 [00:02<00:00, 23780.75it/s]
# Converting MNIST test data...
# 100% 10000/10000 [00:00<00:00, 28996.77it/s]
# Saving MNIST train data...
# Saving MNIST test data...
# MNIST data saved to ./data
#   - Train: (60000, 28, 28), (60000,)
#   - Test: (10000, 28, 28), (10000,)
#
#
# ...
# 100% 170M/170M [00:03<00:00, 43.6MB/s]
# Converting CIFAR-10 train data...
# 100% 50000/50000 [00:02<00:00, 24531.28it/s]
# Converting CIFAR-10 test data...
# 100% 10000/10000 [00:00<00:00, 25409.54it/s]
# Saving CIFAR-10 train data...
# Saving CIFAR-10 test data...
# CIFAR-10 data saved to ./data
#   - Train: (50000, 32, 32, 3), (50000,)
#   - Test: (10000, 32, 32, 3), (10000,)
#
# Data preparation completed!

# %%
# !python main_train.py
# Out:
# Using device: cuda:0
# Feature extraction mode: True
# --------------------------------------------------
#
# [1] Training MNIST AlexNet...
# ...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Params to learn:
# 	 classifier.6.weight
# 	 classifier.6.bias
# 	 classifier.6.weight
# 	 classifier.6.bias
# Epoch 0/9
# --------------------
# train Loss: 0.4426 Acc: 0.8529
#
# val Loss: 0.2517 Acc: 0.9192
#
# Epoch 1/9
# ...

# %%
# !python main_test.py
# Out:
# Using device: cuda:0
# --------------------------------------------------
#
# [1] Loading models...
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# MNIST Model Loaded
#   - Best Accuracy: 0.9564
#   - Trained Epochs: 10
#
# CIFAR-10 Model Loaded
#   - Best Accuracy: 0.7834
#   - Trained Epochs: 10
#
# [2] Testing models...
# ...
# MNIST AlexNet Test Accuracy: 96.88%
# CIFAR-10 AlexNet Test Accuracy: 78.12%
#
# ...

# %%
from IPython.display import Image, display

print("MNIST Training History:")
display(Image('./results/mnist_training_history.png'))

print("\nCIFAR-10 Training History:")
display(Image('./results/cifar_training_history.png'))

print("\nMNIST Wrong Predictions:")
display(Image('./results/mnist_wrong_predictions.png'))

print("\nCIFAR-10 Wrong Predictions:")
display(Image('./results/cifar_wrong_predictions.png'))
# Out:
# MNIST Training History:
# CIFAR-10 Training History:
# MNIST Wrong Predictions:
# CIFAR-10 Wrong Predictions:

# %%
# !git status

# %%
# !git commit -m "[1021] colab 실행 결과"

# %%
# !git checkout main
# !git push origin main

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp -r /content/study-repo/results /content/drive/MyDrive
# !cp -r /content/study-repo/saved_models /content/drive/MyDrive
# Out:
# Mounted at /content/drive
